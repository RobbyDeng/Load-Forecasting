# %%
import numpy as np
import h5py

# %%
f = h5py.File('results.h5','r')
f.keys() #可以查看所有的主键
print([key for key in f.keys()])
# Out:
# ['pred_list']

# %%
print(f['pred_list'][:].shape)
# Out:
# (5, 4, 17544)

# %%
print(f['pred_list'][:])
# Out:
# [[[ 3.0658790e-01  2.8745520e-01  9.9263358e-05 ...  4.2794737e-01
#     3.8204744e-01  3.2718861e-01]
#   [ 3.0032891e-01  2.8509843e-01 -6.5822271e-05 ...  4.2766163e-01
#     3.7621713e-01  3.3395225e-01]
#   [ 3.1745183e-01  3.0220881e-01 -1.4490255e-03 ...  4.3197021e-01
#     3.8476476e-01  3.3090878e-01]
#   [ 3.2922906e-01  3.0625302e-01  2.5757551e-04 ...  4.2515931e-01
#     3.7657157e-01  3.2398561e-01]]
#
#  [[ 3.3174226e-01  3.0990168e-01 -1.3710846e-03 ...  4.3832022e-01
#     3.8944373e-01  3.3822897e-01]
#   [ 3.1004158e-01  2.9769868e-01 -7.2260393e-04 ...  4.4354334e-01
#     3.9639062e-01  3.4951347e-01]
#   [ 3.2082102e-01  3.0077624e-01  7.4045011e-04 ...  4.3682808e-01
#     3.8790676e-01  3.3681792e-01]
#   [ 3.1103209e-01  2.8889912e-01 -9.2933733e-05 ...  4.3533632e-01
#     3.9814457e-01  3.3542117e-01]]
#
#  [[ 3.2216480e-01  3.0242077e-01 -1.0813268e-04 ...  4.3451825e-01
#     3.8299927e-01  3.3129618e-01]
# ...
